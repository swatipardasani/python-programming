# %% [markdown]
# ## Connecting to Bigquery

# %%
# Python GBQ
import pandas_gbq as pd_gbq

# Reading
sql_query = f"select * from `project.dataset.table` limit 10"
df = pd_gbq.read_gbq(sql_query,use_bqstorage_api=True)

# Writing
write_bq_table_name = 'project.dataset.table'
pd_gbq.to_gbq(
    df_results, 
    destination_table="SMB_LOAD.PRODUCT_CODES_PRESENCE",
    project_id="bt-datasci-aif-exp-prod",
    #credentials=credentials,
    #if_exists="replace"
)

# %%
# Bigquery Client
#import google client

# %% [markdown]
# ## Connecting to Cloud Storage

# %%
# Cloud Storage Client

# %% [markdown]
# ## Connecting to Firestore

# %%
# Firestore Client

# %% [markdown]
# ## Connecting To PubSub

# %%
# Pub Sub Client
